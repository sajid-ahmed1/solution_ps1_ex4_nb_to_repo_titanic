# %%
from titanic.data import image_loader

# %%
image_loader('passengers_sex.png')

# %% [markdown]
# Reading from the Kaggle, the survived field is a 1 if they survived and 0 if they did not survive. The male and female counts come from the train and test dataset combined. From this chart, we can see the males on the titanic did not survive as much as the females. We know this is realistic as the women and children were offboarded on the ships first, therefore having a higher survival count.

# %%
image_loader('passengers_pclass.png')

# %% [markdown]
# From this chart, we can see the number of people who survived from each class set. Third class has a lot more deaths and as many survived as first class, but this is due to the total number of people who went on the titanic that were third class.

# %%
image_loader('survival_rate_pclass.png')

# %% [markdown]
# After grouping by the pclass, we can look at the survival rate and it is clear that the order in which their class was, was the reason why their survival rate was high. First class came off the titantic first in the lifeboats, then second class and then third class. Therefore, the sex and the passenger class are very important for the model to predict survival of a person because they mattered in the order of leaving the titanic. If you were a male in third class like Jack, it would be a slim chance of surviving.

# %%
image_loader('survival_age.png')

# %% [markdown]
# The last feature I would include in the selection would be age, the younger the fitter, and therefore could have a higher change of survival after an age. Here 0 is anyone below 16, 1 is 17 to 32, 2 is 33 to 48, 3 is 49 to 64 and 4 is above 64 years old. Those under 16 years of age had a lower chance of surviving, the 1 age interval had the highest passenger count and the highest survival numbers. Therefore, age should be considered a feature as it looks like it determines surivability.
